# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"There are {len(cities)} cities in our database")
# Out:
# There are 784 cities in our database

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# import the requests library
import requests
# Import the OpenWeatherMap's API key
from config import weather_api_key
# weather_api_key = 'bb13fdceacbec1e4654831daabaeff68'

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
print (url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bb13fdceacbec1e4654831daabaeff68

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        latitude = city_weather["coord"]['lat']
        longitude = city_weather["coord"]['lon']
        max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        cloudiness = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]
        country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
            
        # Append the city information into the city_data list
        
        city_data.append({
            "City": city.title(),
            "Lat":latitude,
            "Lng":longitude,
            "Max Temp":max_temp,
            "Humidity":humidity,
            "Cloudiness":cloudiness,
            "Wind Speed":wind,
            "Country":country,
            "Current Description":weather_description
        })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | ribeira grande
# Processing Record 4 of Set 1 | leningradskiy
# Processing Record 5 of Set 1 | chumikan
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | richards bay
# Processing Record 10 of Set 1 | mabaruma
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | vao
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | lompoc
# Processing Record 16 of Set 1 | weinfelden
# Processing Record 17 of Set 1 | cordoba
# Processing Record 18 of Set 1 | nabire
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | kavieng
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | mackenzie
# Processing Record 25 of Set 1 | ayan
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | shache
# Processing Record 28 of Set 1 | sao filipe
# Processing Record 29 of Set 1 | verkhoyansk
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | galle
# Processing Record 32 of Set 1 | westport
# Processing Record 33 of Set 1 | pisco
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | kiama
# Processing Record 36 of Set 1 | hambantota
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | achisay
# City not found. Skipping...
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | poum
# Processing Record 41 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 1 | amapa
# Processing Record 43 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 1 | oyem
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | bonthe
# Processing Record 49 of Set 1 | codrington
# Processing Record 50 of Set 1 | katsuura
# Processing Record 1 of Set 2 | jiwani
# Processing Record 2 of Set 2 | cukai
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | rawson
# Processing Record 5 of Set 2 | hoskote
# Processing Record 6 of Set 2 | yabelo
# Processing Record 7 of Set 2 | zhigansk
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | esperance
# Processing Record 10 of Set 2 | kaili
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | chokurdakh
# Processing Record 14 of Set 2 | narsaq
# Processing Record 15 of Set 2 | lemon tree passage
# Processing Record 16 of Set 2 | caravelas
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | dawei
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | qom
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | uppsala
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | coos bay
# Processing Record 25 of Set 2 | koumac
# Processing Record 26 of Set 2 | iskateley
# Processing Record 27 of Set 2 | harnoli
# Processing Record 28 of Set 2 | channarayapatna
# Processing Record 29 of Set 2 | castro
# Processing Record 30 of Set 2 | saldanha
# Processing Record 31 of Set 2 | luena
# Processing Record 32 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 2 | kaitangata
# Processing Record 34 of Set 2 | grindavik
# Processing Record 35 of Set 2 | belyy yar
# Processing Record 36 of Set 2 | cap malheureux
# Processing Record 37 of Set 2 | hay river
# Processing Record 38 of Set 2 | chico
# Processing Record 39 of Set 2 | banda aceh
# Processing Record 40 of Set 2 | punta arenas
# Processing Record 41 of Set 2 | rio grande
# Processing Record 42 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 43 of Set 2 | namatanai
# Processing Record 44 of Set 2 | srednekolymsk
# Processing Record 45 of Set 2 | lebu
# Processing Record 46 of Set 2 | kununurra
# Processing Record 47 of Set 2 | arraial do cabo
# Processing Record 48 of Set 2 | ostrovnoy
# Processing Record 49 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set 2 | sioux lookout
# Processing Record 1 of Set 3 | lipari
# Processing Record 2 of Set 3 | rubiataba
# Processing Record 3 of Set 3 | mirina
# City not found. Skipping...
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | beyneu
# Processing Record 6 of Set 3 | gerash
# Processing Record 7 of Set 3 | suzu
# City not found. Skipping...
# Processing Record 8 of Set 3 | manokwari
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | hami
# Processing Record 11 of Set 3 | itarema
# Processing Record 12 of Set 3 | mahebourg
# Processing Record 13 of Set 3 | avera
# Processing Record 14 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 3 | talnakh
# Processing Record 16 of Set 3 | butaritari
# Processing Record 17 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 3 | shaunavon
# Processing Record 19 of Set 3 | slyudyanka
# Processing Record 20 of Set 3 | freeport
# Processing Record 21 of Set 3 | puerto escondido
# Processing Record 22 of Set 3 | mareeba
# Processing Record 23 of Set 3 | khatanga
# Processing Record 24 of Set 3 | jutai
# Processing Record 25 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 3 | khandyga
# Processing Record 27 of Set 3 | tasiilaq
# Processing Record 28 of Set 3 | raha
# Processing Record 29 of Set 3 | talaya
# Processing Record 30 of Set 3 | naryan-mar
# Processing Record 31 of Set 3 | gore
# Processing Record 32 of Set 3 | karratha
# Processing Record 33 of Set 3 | pirenopolis
# Processing Record 34 of Set 3 | deputatskiy
# Processing Record 35 of Set 3 | marsa matruh
# Processing Record 36 of Set 3 | kandrian
# Processing Record 37 of Set 3 | mitu
# Processing Record 38 of Set 3 | isangel
# Processing Record 39 of Set 3 | buritis
# Processing Record 40 of Set 3 | pimentel
# Processing Record 41 of Set 3 | vestmannaeyjar
# Processing Record 42 of Set 3 | shimoda
# Processing Record 43 of Set 3 | barrow
# Processing Record 44 of Set 3 | dom pedro
# Processing Record 45 of Set 3 | santa maria
# Processing Record 46 of Set 3 | bulgan
# Processing Record 47 of Set 3 | bilma
# Processing Record 48 of Set 3 | longyearbyen
# Processing Record 49 of Set 3 | puerto ayora
# Processing Record 50 of Set 3 | port hedland
# Processing Record 1 of Set 4 | taloy
# Processing Record 2 of Set 4 | yulara
# Processing Record 3 of Set 4 | lamar
# Processing Record 4 of Set 4 | evensk
# Processing Record 5 of Set 4 | sao joao da barra
# Processing Record 6 of Set 4 | bodden town
# Processing Record 7 of Set 4 | trairi
# Processing Record 8 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 4 | henties bay
# Processing Record 10 of Set 4 | dunedin
# Processing Record 11 of Set 4 | chuy
# Processing Record 12 of Set 4 | cilaos
# Processing Record 13 of Set 4 | cam pha
# City not found. Skipping...
# Processing Record 14 of Set 4 | new norfolk
# Processing Record 15 of Set 4 | uige
# Processing Record 16 of Set 4 | dakar
# Processing Record 17 of Set 4 | labuhan
# Processing Record 18 of Set 4 | bethel
# Processing Record 19 of Set 4 | luangwa
# Processing Record 20 of Set 4 | berbera
# Processing Record 21 of Set 4 | luderitz
# Processing Record 22 of Set 4 | victoria point
# Processing Record 23 of Set 4 | bathsheba
# Processing Record 24 of Set 4 | airai
# Processing Record 25 of Set 4 | bakaly
# Processing Record 26 of Set 4 | provideniya
# Processing Record 27 of Set 4 | clyde river
# Processing Record 28 of Set 4 | schwabisch hall
# Processing Record 29 of Set 4 | noumea
# Processing Record 30 of Set 4 | neiafu
# Processing Record 31 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 4 | ust-nera
# Processing Record 33 of Set 4 | birnin kebbi
# Processing Record 34 of Set 4 | agirish
# Processing Record 35 of Set 4 | norrtalje
# Processing Record 36 of Set 4 | akita
# Processing Record 37 of Set 4 | quang ngai
# Processing Record 38 of Set 4 | qaanaaq
# Processing Record 39 of Set 4 | ponta do sol
# Processing Record 40 of Set 4 | san patricio
# Processing Record 41 of Set 4 | mehran
# Processing Record 42 of Set 4 | yebaishou
# Processing Record 43 of Set 4 | hasaki
# Processing Record 44 of Set 4 | qasigiannguit
# Processing Record 45 of Set 4 | xuddur
# Processing Record 46 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 47 of Set 4 | kawalu
# Processing Record 48 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 4 | kahului
# Processing Record 50 of Set 4 | benguela
# Processing Record 1 of Set 5 | port blair
# Processing Record 2 of Set 5 | pinotepa nacional
# Processing Record 3 of Set 5 | tuatapere
# Processing Record 4 of Set 5 | zhigalovo
# Processing Record 5 of Set 5 | leshukonskoye
# Processing Record 6 of Set 5 | adrar
# Processing Record 7 of Set 5 | ilulissat
# Processing Record 8 of Set 5 | hobart
# Processing Record 9 of Set 5 | kruisfontein
# Processing Record 10 of Set 5 | krasnoselkup
# Processing Record 11 of Set 5 | dikson
# Processing Record 12 of Set 5 | anadyr
# Processing Record 13 of Set 5 | werda
# Processing Record 14 of Set 5 | bogande
# Processing Record 15 of Set 5 | nikolskoye
# Processing Record 16 of Set 5 | vilyuysk
# Processing Record 17 of Set 5 | thompson
# Processing Record 18 of Set 5 | minas
# Processing Record 19 of Set 5 | nicoya
# Processing Record 20 of Set 5 | zhezkazgan
# Processing Record 21 of Set 5 | prince rupert
# Processing Record 22 of Set 5 | yellowknife
# Processing Record 23 of Set 5 | bellavista
# Processing Record 24 of Set 5 | plettenberg bay
# Processing Record 25 of Set 5 | cherskiy
# Processing Record 26 of Set 5 | portland
# Processing Record 27 of Set 5 | pangoa
# Processing Record 28 of Set 5 | taoudenni
# Processing Record 29 of Set 5 | saint anthony
# Processing Record 30 of Set 5 | imbituba
# Processing Record 31 of Set 5 | touros
# Processing Record 32 of Set 5 | grand-lahou
# Processing Record 33 of Set 5 | monte alegre
# Processing Record 34 of Set 5 | at-bashi
# Processing Record 35 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 5 | nhulunbuy
# Processing Record 37 of Set 5 | isla vista
# Processing Record 38 of Set 5 | chala
# Processing Record 39 of Set 5 | erenhot
# Processing Record 40 of Set 5 | tezu
# Processing Record 41 of Set 5 | tupik
# Processing Record 42 of Set 5 | mae sai
# Processing Record 43 of Set 5 | nyurba
# Processing Record 44 of Set 5 | guerrero negro
# Processing Record 45 of Set 5 | lefka
# Processing Record 46 of Set 5 | chom bung
# City not found. Skipping...
# Processing Record 47 of Set 5 | bontang
# Processing Record 48 of Set 5 | ascension
# Processing Record 49 of Set 5 | pevek
# Processing Record 50 of Set 5 | xam nua
# Processing Record 1 of Set 6 | glenwood springs
# Processing Record 2 of Set 6 | chontalpa
# Processing Record 3 of Set 6 | kutum
# Processing Record 4 of Set 6 | mahina
# Processing Record 5 of Set 6 | sulphur springs
# Processing Record 6 of Set 6 | sankt georgen
# Processing Record 7 of Set 6 | sfantu gheorghe
# Processing Record 8 of Set 6 | vila velha
# Processing Record 9 of Set 6 | kleck
# City not found. Skipping...
# Processing Record 10 of Set 6 | carnarvon
# Processing Record 11 of Set 6 | murray bridge
# Processing Record 12 of Set 6 | tefe
# Processing Record 13 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 6 | dingle
# Processing Record 16 of Set 6 | ada
# Processing Record 17 of Set 6 | dejen
# Processing Record 18 of Set 6 | sergeyevka
# Processing Record 19 of Set 6 | bridlington
# Processing Record 20 of Set 6 | boysun
# Processing Record 21 of Set 6 | jiuquan
# Processing Record 22 of Set 6 | kavaratti
# Processing Record 23 of Set 6 | pafos
# Processing Record 24 of Set 6 | bima
# Processing Record 25 of Set 6 | denpasar
# Processing Record 26 of Set 6 | roebourne
# Processing Record 27 of Set 6 | yeppoon
# Processing Record 28 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 29 of Set 6 | gallup
# Processing Record 30 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 6 | vostok
# Processing Record 32 of Set 6 | fairbanks
# Processing Record 33 of Set 6 | okhotsk
# Processing Record 34 of Set 6 | jitra
# Processing Record 35 of Set 6 | sisimiut
# Processing Record 36 of Set 6 | norman wells
# Processing Record 37 of Set 6 | seymchan
# Processing Record 38 of Set 6 | horsham
# Processing Record 39 of Set 6 | iracoubo
# Processing Record 40 of Set 6 | jesenice
# Processing Record 41 of Set 6 | bubaque
# Processing Record 42 of Set 6 | kamyshevatskaya
# Processing Record 43 of Set 6 | bengkulu
# Processing Record 44 of Set 6 | chegdomyn
# Processing Record 45 of Set 6 | ciudad valles
# Processing Record 46 of Set 6 | faanui
# Processing Record 47 of Set 6 | te anau
# Processing Record 48 of Set 6 | illapel
# Processing Record 49 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 50 of Set 6 | san quintin
# Processing Record 1 of Set 7 | qostanay
# Processing Record 2 of Set 7 | shu
# Processing Record 3 of Set 7 | laguna
# Processing Record 4 of Set 7 | pontianak
# Processing Record 5 of Set 7 | kirakira
# Processing Record 6 of Set 7 | tessalit
# Processing Record 7 of Set 7 | aguimes
# Processing Record 8 of Set 7 | cidreira
# Processing Record 9 of Set 7 | nishihara
# Processing Record 10 of Set 7 | soe
# Processing Record 11 of Set 7 | sur
# Processing Record 12 of Set 7 | lichuan
# Processing Record 13 of Set 7 | meulaboh
# Processing Record 14 of Set 7 | port augusta
# Processing Record 15 of Set 7 | palmer
# Processing Record 16 of Set 7 | naze
# Processing Record 17 of Set 7 | maceio
# Processing Record 18 of Set 7 | christchurch
# Processing Record 19 of Set 7 | milledgeville
# Processing Record 20 of Set 7 | ahipara
# Processing Record 21 of Set 7 | macas
# Processing Record 22 of Set 7 | gorontalo
# Processing Record 23 of Set 7 | pangnirtung
# Processing Record 24 of Set 7 | makakilo city
# Processing Record 25 of Set 7 | abu samrah
# Processing Record 26 of Set 7 | oriximina
# Processing Record 27 of Set 7 | magole
# Processing Record 28 of Set 7 | port hawkesbury
# Processing Record 29 of Set 7 | dixon
# Processing Record 30 of Set 7 | byron bay
# Processing Record 31 of Set 7 | pucallpa
# Processing Record 32 of Set 7 | sekoma
# Processing Record 33 of Set 7 | tawnat
# City not found. Skipping...
# Processing Record 34 of Set 7 | yingkou
# Processing Record 35 of Set 7 | akyab
# Processing Record 36 of Set 7 | masvingo
# Processing Record 37 of Set 7 | namibe
# Processing Record 38 of Set 7 | paamiut
# Processing Record 39 of Set 7 | hanstholm
# Processing Record 40 of Set 7 | antigonish
# Processing Record 41 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 43 of Set 7 | lagos
# Processing Record 44 of Set 7 | saint-augustin
# Processing Record 45 of Set 7 | nuuk
# Processing Record 46 of Set 7 | soyo
# Processing Record 47 of Set 7 | vila
# Processing Record 48 of Set 7 | nanortalik
# Processing Record 49 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 7 | ambilobe
# Processing Record 1 of Set 8 | saint-louis
# Processing Record 2 of Set 8 | oussouye
# Processing Record 3 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 4 of Set 8 | rocky mountain house
# Processing Record 5 of Set 8 | bambous virieux
# Processing Record 6 of Set 8 | shitanjing
# Processing Record 7 of Set 8 | the valley
# Processing Record 8 of Set 8 | eskilstuna
# Processing Record 9 of Set 8 | tucumcari
# Processing Record 10 of Set 8 | kieta
# Processing Record 11 of Set 8 | shchors
# Processing Record 12 of Set 8 | amarkantak
# Processing Record 13 of Set 8 | terney
# Processing Record 14 of Set 8 | port macquarie
# Processing Record 15 of Set 8 | coahuayana
# Processing Record 16 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 17 of Set 8 | tursunzoda
# Processing Record 18 of Set 8 | lingsugur
# Processing Record 19 of Set 8 | yuanping
# Processing Record 20 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 8 | guozhen
# Processing Record 22 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 23 of Set 8 | balaka
# Processing Record 24 of Set 8 | solnechnyy
# Processing Record 25 of Set 8 | pasighat
# Processing Record 26 of Set 8 | svetlaya
# Processing Record 27 of Set 8 | bedesa
# Processing Record 28 of Set 8 | puerto penasco
# Processing Record 29 of Set 8 | lahaina
# Processing Record 30 of Set 8 | cockburn town
# Processing Record 31 of Set 8 | nieuw amsterdam
# Processing Record 32 of Set 8 | grand gaube
# Processing Record 33 of Set 8 | salalah
# Processing Record 34 of Set 8 | myitkyina
# Processing Record 35 of Set 8 | dzaoudzi
# Processing Record 36 of Set 8 | aras
# Processing Record 37 of Set 8 | ocos
# Processing Record 38 of Set 8 | lang son
# Processing Record 39 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 40 of Set 8 | rothrist
# Processing Record 41 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 8 | tashtagol
# Processing Record 43 of Set 8 | zaigrayevo
# Processing Record 44 of Set 8 | lagoa
# Processing Record 45 of Set 8 | arcachon
# Processing Record 46 of Set 8 | oranjemund
# Processing Record 47 of Set 8 | otradinskiy
# City not found. Skipping...
# Processing Record 48 of Set 8 | strangnas
# Processing Record 49 of Set 8 | pitanga
# Processing Record 50 of Set 8 | urumqi
# Processing Record 1 of Set 9 | aykhal
# Processing Record 2 of Set 9 | praxedis guerrero
# Processing Record 3 of Set 9 | los llanos de aridane
# Processing Record 4 of Set 9 | inuvik
# Processing Record 5 of Set 9 | acarau
# Processing Record 6 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 9 | garissa
# Processing Record 8 of Set 9 | whitianga
# Processing Record 9 of Set 9 | arlit
# Processing Record 10 of Set 9 | roald
# Processing Record 11 of Set 9 | astrea
# Processing Record 12 of Set 9 | hofn
# Processing Record 13 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 9 | pochutla
# Processing Record 15 of Set 9 | kargasok
# Processing Record 16 of Set 9 | tual
# Processing Record 17 of Set 9 | victoria
# Processing Record 18 of Set 9 | sayalgudi
# City not found. Skipping...
# Processing Record 19 of Set 9 | oudenburg
# Processing Record 20 of Set 9 | kolokani
# Processing Record 21 of Set 9 | port hardy
# Processing Record 22 of Set 9 | berlevag
# Processing Record 23 of Set 9 | yar-sale
# Processing Record 24 of Set 9 | kenai
# Processing Record 25 of Set 9 | ust-koksa
# Processing Record 26 of Set 9 | wawa
# Processing Record 27 of Set 9 | baisha
# Processing Record 28 of Set 9 | umm lajj
# Processing Record 29 of Set 9 | kodinsk
# Processing Record 30 of Set 9 | vila franca do campo
# Processing Record 31 of Set 9 | mutoko
# Processing Record 32 of Set 9 | monster
# Processing Record 33 of Set 9 | jambi
# Processing Record 34 of Set 9 | varhaug
# Processing Record 35 of Set 9 | bolotnoye
# Processing Record 36 of Set 9 | napier
# Processing Record 37 of Set 9 | clearwater
# Processing Record 38 of Set 9 | port elizabeth
# Processing Record 39 of Set 9 | vanimo
# Processing Record 40 of Set 9 | arawa
# Processing Record 41 of Set 9 | mangan
# Processing Record 42 of Set 9 | mouila
# Processing Record 43 of Set 9 | linxi
# Processing Record 44 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 9 | san jose de guanipa
# Processing Record 46 of Set 9 | fuerte olimpo
# Processing Record 47 of Set 9 | ahuimanu
# Processing Record 48 of Set 9 | hongjiang
# Processing Record 49 of Set 9 | nelson bay
# Processing Record 50 of Set 9 | vaitape
# Processing Record 1 of Set 10 | huaicheng
# Processing Record 2 of Set 10 | opuwo
# Processing Record 3 of Set 10 | cabo san lucas
# Processing Record 4 of Set 10 | kaeo
# Processing Record 5 of Set 10 | sinnamary
# Processing Record 6 of Set 10 | alyangula
# Processing Record 7 of Set 10 | taltal
# Processing Record 8 of Set 10 | wonthaggi
# Processing Record 9 of Set 10 | mount gambier
# Processing Record 10 of Set 10 | broome
# Processing Record 11 of Set 10 | kannur
# Processing Record 12 of Set 10 | ewa beach
# Processing Record 13 of Set 10 | viedma
# Processing Record 14 of Set 10 | springfield
# Processing Record 15 of Set 10 | lorengau
# Processing Record 16 of Set 10 | maragogi
# Processing Record 17 of Set 10 | novokizhinginsk
# Processing Record 18 of Set 10 | klaksvik
# Processing Record 19 of Set 10 | melita
# Processing Record 20 of Set 10 | rondonopolis
# Processing Record 21 of Set 10 | mapiripan
# Processing Record 22 of Set 10 | bereda
# Processing Record 23 of Set 10 | cascais
# Processing Record 24 of Set 10 | coihaique
# Processing Record 25 of Set 10 | ixtapa
# Processing Record 26 of Set 10 | vieux-habitants
# Processing Record 27 of Set 10 | sortland
# Processing Record 28 of Set 10 | payo
# Processing Record 29 of Set 10 | san vicente
# Processing Record 30 of Set 10 | vigrestad
# Processing Record 31 of Set 10 | menongue
# Processing Record 32 of Set 10 | nouadhibou
# Processing Record 33 of Set 10 | baruun-urt
# Processing Record 34 of Set 10 | chapais
# Processing Record 35 of Set 10 | gavle
# Processing Record 36 of Set 10 | kerman
# Processing Record 37 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 10 | nongan
# Processing Record 39 of Set 10 | staunton
# Processing Record 40 of Set 10 | anloga
# Processing Record 41 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 10 | lerwick
# Processing Record 43 of Set 10 | beroroha
# Processing Record 44 of Set 10 | gabu
# Processing Record 45 of Set 10 | coquimbo
# Processing Record 46 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 47 of Set 10 | capreol
# Processing Record 48 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 49 of Set 10 | burica
# City not found. Skipping...
# Processing Record 50 of Set 10 | rosita
# Processing Record 1 of Set 11 | general pico
# Processing Record 2 of Set 11 | komsomolskiy
# Processing Record 3 of Set 11 | tiarei
# Processing Record 4 of Set 11 | xining
# Processing Record 5 of Set 11 | mar del plata
# Processing Record 6 of Set 11 | toulepleu
# City not found. Skipping...
# Processing Record 7 of Set 11 | mwanza
# Processing Record 8 of Set 11 | waipawa
# Processing Record 9 of Set 11 | buzdyak
# Processing Record 10 of Set 11 | murgab
# Processing Record 11 of Set 11 | conceicao do araguaia
# Processing Record 12 of Set 11 | bayan
# Processing Record 13 of Set 11 | santa rosa
# Processing Record 14 of Set 11 | ha tinh
# Processing Record 15 of Set 11 | devgarh
# Processing Record 16 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 11 | bensonville
# Processing Record 18 of Set 11 | cayenne
# Processing Record 19 of Set 11 | goderich
# Processing Record 20 of Set 11 | nalut
# Processing Record 21 of Set 11 | hamilton
# Processing Record 22 of Set 11 | shelburne
# Processing Record 23 of Set 11 | sri aman
# Processing Record 24 of Set 11 | qixingtai
# Processing Record 25 of Set 11 | aasiaat
# Processing Record 26 of Set 11 | kaitong
# Processing Record 27 of Set 11 | lavrentiya
# Processing Record 28 of Set 11 | nemuro
# Processing Record 29 of Set 11 | bhag
# Processing Record 30 of Set 11 | geraldton
# Processing Record 31 of Set 11 | fortuna foothills
# Processing Record 32 of Set 11 | linjiang
# Processing Record 33 of Set 11 | ambon
# Processing Record 34 of Set 11 | banfora
# Processing Record 35 of Set 11 | achutupo
# Processing Record 36 of Set 11 | kingsville
# Processing Record 37 of Set 11 | ust-maya
# Processing Record 38 of Set 11 | esna
# Processing Record 39 of Set 11 | monrovia
# Processing Record 40 of Set 11 | kibre mengist
# Processing Record 41 of Set 11 | reconquista
# Processing Record 42 of Set 11 | truth or consequences
# Processing Record 43 of Set 11 | boa vista
# Processing Record 44 of Set 11 | lakatoro
# Processing Record 45 of Set 11 | puerto baquerizo moreno
# Processing Record 46 of Set 11 | iqaluit
# Processing Record 47 of Set 11 | vung tau
# Processing Record 48 of Set 11 | port lincoln
# Processing Record 49 of Set 11 | bose
# Processing Record 50 of Set 11 | shatrovo
# Processing Record 1 of Set 12 | alofi
# Processing Record 2 of Set 12 | barguzin
# Processing Record 3 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 12 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 12 | usinsk
# Processing Record 6 of Set 12 | rochefort
# Processing Record 7 of Set 12 | abu kamal
# Processing Record 8 of Set 12 | marawi
# Processing Record 9 of Set 12 | constitucion
# Processing Record 10 of Set 12 | poya
# Processing Record 11 of Set 12 | beringovskiy
# Processing Record 12 of Set 12 | chicama
# Processing Record 13 of Set 12 | creel
# Processing Record 14 of Set 12 | hailey
# Processing Record 15 of Set 12 | yakshur-bodya
# City not found. Skipping...
# Processing Record 16 of Set 12 | hanting
# Processing Record 17 of Set 12 | fortuna
# Processing Record 18 of Set 12 | aden
# Processing Record 19 of Set 12 | mecca
# Processing Record 20 of Set 12 | ust-ishim
# Processing Record 21 of Set 12 | moron
# Processing Record 22 of Set 12 | san cristobal
# Processing Record 23 of Set 12 | mweka
# Processing Record 24 of Set 12 | san ramon
# Processing Record 25 of Set 12 | brae
# Processing Record 26 of Set 12 | wattegama
# Processing Record 27 of Set 12 | atikokan
# Processing Record 28 of Set 12 | ancud
# Processing Record 29 of Set 12 | catalao
# Processing Record 30 of Set 12 | buala
# Processing Record 31 of Set 12 | olafsvik
# Processing Record 32 of Set 12 | hualmay
# Processing Record 33 of Set 12 | boyolangu
# Processing Record 34 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 12 | quirinopolis
# Processing Record 36 of Set 12 | fukue
# Processing Record 37 of Set 12 | tutoia
# Processing Record 38 of Set 12 | subaytilah
# City not found. Skipping...
# Processing Record 39 of Set 12 | indianola
# Processing Record 40 of Set 12 | bardiyah
# Processing Record 41 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 42 of Set 12 | gat
# Processing Record 43 of Set 12 | udachnyy
# Processing Record 44 of Set 12 | kurilsk
# Processing Record 45 of Set 12 | mossendjo
# Processing Record 46 of Set 12 | stillwater
# Processing Record 47 of Set 12 | rajanpur
# Processing Record 48 of Set 12 | belfast
# Processing Record 49 of Set 12 | sao miguel do araguaia
# Processing Record 50 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 13 | svetlogorsk
# Processing Record 2 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 3 of Set 13 | requena
# Processing Record 4 of Set 13 | ginda
# Processing Record 5 of Set 13 | aksha
# Processing Record 6 of Set 13 | concordia
# Processing Record 7 of Set 13 | hauterive
# Processing Record 8 of Set 13 | sitka
# Processing Record 9 of Set 13 | peterhead
# Processing Record 10 of Set 13 | lengshuitan
# Processing Record 11 of Set 13 | jalu
# Processing Record 12 of Set 13 | atbasar
# Processing Record 13 of Set 13 | filadelfia
# Processing Record 14 of Set 13 | khani
# Processing Record 15 of Set 13 | lasa
# Processing Record 16 of Set 13 | kankon
# Processing Record 17 of Set 13 | mgandu
# Processing Record 18 of Set 13 | san andres
# Processing Record 19 of Set 13 | barda
# Processing Record 20 of Set 13 | masumbwe
# Processing Record 21 of Set 13 | yakeshi
# Processing Record 22 of Set 13 | turayf
# Processing Record 23 of Set 13 | lata
# Processing Record 24 of Set 13 | agar
# Processing Record 25 of Set 13 | uren
# Processing Record 26 of Set 13 | marsh harbour
# Processing Record 27 of Set 13 | tres palos
# Processing Record 28 of Set 13 | sorland
# Processing Record 29 of Set 13 | magadan
# Processing Record 30 of Set 13 | bunia
# Processing Record 31 of Set 13 | fort smith
# Processing Record 32 of Set 13 | barcelos
# Processing Record 33 of Set 13 | tucupita
# Processing Record 34 of Set 13 | shingu
# Processing Record 35 of Set 13 | rocha
# Processing Record 36 of Set 13 | atar
# Processing Record 37 of Set 13 | sungaipenuh
# Processing Record 38 of Set 13 | surt
# Processing Record 39 of Set 13 | husavik
# Processing Record 40 of Set 13 | saint george
# Processing Record 41 of Set 13 | dajabon
# Processing Record 42 of Set 13 | humaita
# Processing Record 43 of Set 13 | apac
# Processing Record 44 of Set 13 | bulnes
# Processing Record 45 of Set 13 | voh
# Processing Record 46 of Set 13 | roma
# Processing Record 47 of Set 13 | sobolevo
# Processing Record 48 of Set 13 | baherden
# Processing Record 49 of Set 13 | wagar
# Processing Record 50 of Set 13 | popondetta
# Processing Record 1 of Set 14 | huarmey
# Processing Record 2 of Set 14 | yaan
# Processing Record 3 of Set 14 | swinoujscie
# Processing Record 4 of Set 14 | masyaf
# Processing Record 5 of Set 14 | aitape
# Processing Record 6 of Set 14 | batticaloa
# Processing Record 7 of Set 14 | gazojak
# Processing Record 8 of Set 14 | rurrenabaque
# Processing Record 9 of Set 14 | topolobampo
# Processing Record 10 of Set 14 | adre
# Processing Record 11 of Set 14 | meadow lake
# Processing Record 12 of Set 14 | baracoa
# Processing Record 13 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 14 of Set 14 | hot springs
# Processing Record 15 of Set 14 | oktyabrskoye
# Processing Record 16 of Set 14 | gigmoto
# Processing Record 17 of Set 14 | carbonia
# Processing Record 18 of Set 14 | ajdabiya
# Processing Record 19 of Set 14 | uthal
# Processing Record 20 of Set 14 | cornwall
# Processing Record 21 of Set 14 | qaqortoq
# Processing Record 22 of Set 14 | vilani
# Processing Record 23 of Set 14 | jacqueville
# Processing Record 24 of Set 14 | ponta delgada
# Processing Record 25 of Set 14 | ternate
# Processing Record 26 of Set 14 | kropotkin
# Processing Record 27 of Set 14 | sao joao do piaui
# Processing Record 28 of Set 14 | hebi
# Processing Record 29 of Set 14 | wukari
# Processing Record 30 of Set 14 | zelezny brod
# Processing Record 31 of Set 14 | kenmare
# Processing Record 32 of Set 14 | solvychegodsk
# Processing Record 33 of Set 14 | faya
# Processing Record 34 of Set 14 | sabathu
# Processing Record 35 of Set 14 | bilibino
# Processing Record 36 of Set 14 | souillac
# Processing Record 37 of Set 14 | vyartsilya
# Processing Record 38 of Set 14 | harper
# Processing Record 39 of Set 14 | ocosingo
# Processing Record 40 of Set 14 | hastings
# Processing Record 41 of Set 14 | chabahar
# Processing Record 42 of Set 14 | flinders
# Processing Record 43 of Set 14 | quatre cocos
# Processing Record 44 of Set 14 | rock sound
# Processing Record 45 of Set 14 | saint-pierre
# Processing Record 46 of Set 14 | digapahandi
# Processing Record 47 of Set 14 | ciudad guayana
# Processing Record 48 of Set 14 | hukuntsi
# Processing Record 49 of Set 14 | ketchikan
# Processing Record 50 of Set 14 | fergus falls
# Processing Record 1 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 2 of Set 15 | hrodna
# Processing Record 3 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 15 | arkhara
# Processing Record 5 of Set 15 | hima
# Processing Record 6 of Set 15 | itaituba
# Processing Record 7 of Set 15 | waingapu
# Processing Record 8 of Set 15 | hazorasp
# Processing Record 9 of Set 15 | salta
# Processing Record 10 of Set 15 | daru
# Processing Record 11 of Set 15 | buta
# Processing Record 12 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 13 of Set 15 | mehamn
# Processing Record 14 of Set 15 | miranda
# Processing Record 15 of Set 15 | novo oriente
# Processing Record 16 of Set 15 | hearst
# Processing Record 17 of Set 15 | nome
# Processing Record 18 of Set 15 | eyl
# Processing Record 19 of Set 15 | whitehorse
# Processing Record 20 of Set 15 | vite
# Processing Record 21 of Set 15 | robertsport
# Processing Record 22 of Set 15 | calama
# Processing Record 23 of Set 15 | sinjar
# Processing Record 24 of Set 15 | kautokeino
# Processing Record 25 of Set 15 | nokaneng
# Processing Record 26 of Set 15 | tupancireta
# Processing Record 27 of Set 15 | akdepe
# Processing Record 28 of Set 15 | jaguey grande
# Processing Record 29 of Set 15 | saquena
# Processing Record 30 of Set 15 | aswan
# Processing Record 31 of Set 15 | kenitra
# Processing Record 32 of Set 15 | stepnyak
# Processing Record 33 of Set 15 | mwinilunga
# Processing Record 34 of Set 15 | samarai
# Processing Record 35 of Set 15 | palauig
# Processing Record 36 of Set 15 | tevaitoa
# Processing Record 37 of Set 15 | mogadishu
# Processing Record 38 of Set 15 | braganca
# Processing Record 39 of Set 15 | carutapera
# Processing Record 40 of Set 15 | half moon bay
# Processing Record 41 of Set 15 | derby
# Processing Record 42 of Set 15 | roura
# Processing Record 43 of Set 15 | betong
# Processing Record 44 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 45 of Set 15 | jilib
# Processing Record 46 of Set 15 | weligama
# Processing Record 47 of Set 15 | strezhevoy
# Processing Record 48 of Set 15 | almunecar
# Processing Record 49 of Set 15 | gwadar
# Processing Record 50 of Set 15 | marquette
# Processing Record 1 of Set 16 | benicarlo
# Processing Record 2 of Set 16 | honiara
# Processing Record 3 of Set 16 | punta alta
# Processing Record 4 of Set 16 | lar gerd
# City not found. Skipping...
# Processing Record 5 of Set 16 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 16 | hovd
# Processing Record 7 of Set 16 | lazaro cardenas
# Processing Record 8 of Set 16 | iquique
# Processing Record 9 of Set 16 | sindand
# City not found. Skipping...
# Processing Record 10 of Set 16 | rusape
# Processing Record 11 of Set 16 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 12 of Set 16 | simao
# Processing Record 13 of Set 16 | almaznyy
# Processing Record 14 of Set 16 | linxia
# Processing Record 15 of Set 16 | dalbandin
# Processing Record 16 of Set 16 | osakarovka
# Processing Record 17 of Set 16 | saint-joseph
# Processing Record 18 of Set 16 | ures
# Processing Record 19 of Set 16 | necochea
# Processing Record 20 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 16 | pombas
# Processing Record 22 of Set 16 | healdsburg
# Processing Record 23 of Set 16 | tasbuget
# City not found. Skipping...
# Processing Record 24 of Set 16 | bafata
# Processing Record 25 of Set 16 | valleyview
# Processing Record 26 of Set 16 | abu dhabi
# Processing Record 27 of Set 16 | serebryansk
# Processing Record 28 of Set 16 | mawlaik
# Processing Record 29 of Set 16 | achacachi
# Processing Record 30 of Set 16 | acajutla
# Processing Record 31 of Set 16 | asfi
# Processing Record 32 of Set 16 | alexandria
# Processing Record 33 of Set 16 | mogochin
# City not found. Skipping...
# Processing Record 34 of Set 16 | pokosnoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 715

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Georgetown   5.4112  100.3354     89.53        63          20
# 1         Rikitea -23.1203 -134.9692     77.76        74          52
# 2  Ribeira Grande  38.5167  -28.7000     60.78        77          70
# 3   Leningradskiy  69.3833  178.4167    -15.66        97          44
# 4        Chumikan  54.7183  135.3150      3.36        82          39
# 5     Tuktoyaktuk  69.4541 -133.0374    -14.22        98          88
# 6     Port Alfred -33.5906   26.8910     70.18        78           0
# 7  Saint-Philippe -21.3585   55.7679     85.59        72          24
# 8    Richards Bay -28.7830   32.0377     71.10        89         100
# 9        Mabaruma   8.2000  -59.7833     71.40        99          64
#
#    Wind Speed Country Current Description
# 0       12.66      MY          few clouds
# 1        6.98      PF       broken clouds
# 2       15.01      PT       broken clouds
# 3        4.63      RU    scattered clouds
# 4       13.82      RU    scattered clouds
# 5       11.21      CA     overcast clouds
# 6        4.00      ZA           clear sky
# 7       11.74      RE          few clouds
# 8        4.34      ZA     overcast clouds
# 9        3.09      GY       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_names = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df.reindex(columns=column_names)

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Georgetown      MY   5.4112  100.3354     89.53        63          20
# 1         Rikitea      PF -23.1203 -134.9692     77.76        74          52
# 2  Ribeira Grande      PT  38.5167  -28.7000     60.78        77          70
# 3   Leningradskiy      RU  69.3833  178.4167    -15.66        97          44
# 4        Chumikan      RU  54.7183  135.3150      3.36        82          39
# 5     Tuktoyaktuk      CA  69.4541 -133.0374    -14.22        98          88
# 6     Port Alfred      ZA -33.5906   26.8910     70.18        78           0
# 7  Saint-Philippe      RE -21.3585   55.7679     85.59        72          24
# 8    Richards Bay      ZA -28.7830   32.0377     71.10        89         100
# 9        Mabaruma      GY   8.2000  -59.7833     71.40        99          64
#
#    Wind Speed Current Description
# 0       12.66          few clouds
# 1        6.98       broken clouds
# 2       15.01       broken clouds
# 3        4.63    scattered clouds
# 4       13.82    scattered clouds
# 5       11.21     overcast clouds
# 6        4.00           clear sky
# 7       11.74          few clouds
# 8        4.34     overcast clouds
# 9        3.09       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
